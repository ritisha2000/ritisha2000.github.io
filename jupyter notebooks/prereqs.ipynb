# %%
import pandas as pd

# %%
course_list = pd.read_excel('data\Course_Section_Search_-_Central.xlsx')
course_list.columns
# Out:
# Index(['Course Subject', 'Course Number', 'Course', 'Keep/Remove',
#        'Special Topic', 'Section Number', 'Academic Level',
#        'Academic Unit of Section', 'Section', 'Section Status',
#        'Section Title', 'Academic Period', 'Term', 'Start Date', 'End Date',
#        'Hidden Course Section', 'Allowed Grading Bases', 'Eligbility Rules',
#        'Number of Registered Students',
#        'Number of Active Pending Course Opening Notifications',
#        'Number of Active Expired Course Opening Notifications',
#        'Number of Waitlisted Students',
#        'Number of Registered Students and Active Course Opening Notifications',
#        'Reserved Capacity', 'Section Capacity', 'Projected Enrollment',
#        'Reserved Capacity Eligibility Rules', 'Wait List Capacity',
#        'Manually Manage Waitlist Promotion', 'Abbreviated Section Title',
#        'Description', 'Private Notes', 'Public Notes', 'Minimum Credits',
#        'Maximum Credits', 'Credit Type',
#        'Course Tags (from the current version of the course)',
#        'Course Section Tags', 'Instructional Format',
#        'Instructional Format Controls Grading', 'Delivery Mode', 'Instructor',
#        'Meeting Pattern and Location', 'Offering Percent',
#        'Course Section Overlaps'],
#       dtype='object')

# %%
course_list = course_list.drop_duplicates(subset='Course')
course_list.shape
# Out:
# (34, 45)

# %%
course_list['Description']
# Out:
# 0      Measurement of positions, motions, and distanc...
# 1      Structure and kinematics of our galaxy. Spiral...
# 2      Introduction to the study of the Universe as a...
# 3      Astronomical instrumentation and techniques fo...
# 4      Experiments in the use of astronomical instrum...
# 5      The principles of cellular and molecular biolo...
# 25     Concepts fundamental to biological issues, suc...
# 26     Principles of storage and transmission of gene...
# 30     Structure and function of plant and animal cel...
# 40     Animal development and its underlying causal p...
# 43     The principles of biology with particular refe...
# 45     Fundamentals of chemical reactivity: thermodyn...
# 75     Sets and functions; induction; cardinality;  p...
# 77     Biodiversity from an evolutionary perspective....
# 78     Atomic and molecular properties, chemical reac...
# 79     Intensive course with required tutorial. Combi...
# 81     Fundamentals of bonding theories, structural c...
# 82     An introduction to the principles and techniqu...
# 83     Fundamentals of bonding theories and structura...
# 84     Electricity and magnetism, electrical circuits...
# 89     Bonding theories, their predictions, experimen...
# 90     Small-group experience where students study sc...
# 142    Credit will be granted for only one of CHEM 46...
# 143    Effective communication and presentation skill...
# 147    A variety of topics in mathematics, showcasing...
# 261    Mathematical methods in modelling biological p...
# 263    Formulation and analysis of models of excitabl...
# 268    Kinematics, force, energy, momentum, use of gr...
# 269    Classical mechanics including conservation law...
# 311    Kinematics including curvilinear motion. Force...
# 316    Approved and supervised technical work experie...
# 337    An innovative first-year multi-disciplinary co...
# 341    Seminar for First-Year Focus option focused on...
# 426    Overview of methodological approaches to educa...
# Name: Description, dtype: object

# %%
import re

course_description = course_list[['Course', 'Description']]
course_description.loc[:, 'reqs'] = course_description['Description'].str.extract(
    r'((prerequisite|corequisite)[\s\S]*)', 
    flags=re.IGNORECASE
)[0]
course_description
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_4612\2272457247.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_description.loc[:, 'reqs'] = course_description['Description'].str.extract(
#          Course                                        Description  \
# 0    ASTR_V 205  Measurement of positions, motions, and distanc...
# 1    ASTR_V 300  Structure and kinematics of our galaxy. Spiral...
# 2    ASTR_V 403  Introduction to the study of the Universe as a...
# 3    ASTR_V 404  Astronomical instrumentation and techniques fo...
# 4    ASTR_V 405  Experiments in the use of astronomical instrum...
# 5    BIOL_V 112  The principles of cellular and molecular biolo...
# 25   BIOL_V 111  Concepts fundamental to biological issues, suc...
# 26   BIOL_V 121  Principles of storage and transmission of gene...
# 30   BIOL_V 200  Structure and function of plant and animal cel...
# 40   BIOL_V 331  Animal development and its underlying causal p...
# 43   BIOL_V 155  The principles of biology with particular refe...
# 45   CHEM_V 123  Fundamentals of chemical reactivity: thermodyn...
# 75   MATH_V 220  Sets and functions; induction; cardinality;  p...
# 77   BIOL_V 417  Biodiversity from an evolutionary perspective....
# 78   CHEM_V 100  Atomic and molecular properties, chemical reac...
# 79   MATH_V 335  Intensive course with required tutorial. Combi...
# 81   CHEM_V 111  Fundamentals of bonding theories, structural c...
# 82   CHEM_V 115  An introduction to the principles and techniqu...
# 83   CHEM_V 121  Fundamentals of bonding theories and structura...
# 84   PHYS_V 108  Electricity and magnetism, electrical circuits...
# 89   CHEM_V 141  Bonding theories, their predictions, experimen...
# 90   SCIE_V 113  Small-group experience where students study sc...
# 142  CHEM_V 560  Credit will be granted for only one of CHEM 46...
# 143  SCIE_V 300  Effective communication and presentation skill...
# 147  MATH_V 230  A variety of topics in mathematics, showcasing...
# 261  MATH_V 560  Mathematical methods in modelling biological p...
# 263  MATH_V 562  Formulation and analysis of models of excitabl...
# 268  PHYS_V 100  Kinematics, force, energy, momentum, use of gr...
# 269  PHYS_V 106  Classical mechanics including conservation law...
# 311  PHYS_V 117  Kinematics including curvilinear motion. Force...
# 316  PHYS_V 499  Approved and supervised technical work experie...
# 337  SCIE_V 001  An innovative first-year multi-disciplinary co...
# 341  SCIE_V 100  Seminar for First-Year Focus option focused on...
# 426  SCIE_V 500  Overview of methodological approaches to educa...
#
#                                                   reqs
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2    Prerequisite: One of PHYS 200, PHYS 250. ASTR ...
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25                                                 NaN
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79                                                 NaN
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 90                                                 NaN
# 142                                                NaN
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 2...
# 147                                                NaN
# 261                                                NaN
# 263                                                NaN
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311  Prerequisite: One of PHYS 12, PHYS 100. Corequ...
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341                                                NaN
# 426                                                NaN

# %%
course_description['reqs'][78]
# Out:
# 'Prerequisite: Not open to students with credit for Chemistry 12.  Permission of the department head.'

# %%
pattern = r'\b[A-Z]{4}\s\d{3}\sis\srecommended\.'

# Remove the sentence if present
course_description['reqs'] = course_description['reqs'].str.replace(pattern, '', regex=True)
course_description
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_4612\288747870.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_description['reqs'] = course_description['reqs'].str.replace(pattern, '', regex=True)
#          Course                                        Description  \
# 0    ASTR_V 205  Measurement of positions, motions, and distanc...
# 1    ASTR_V 300  Structure and kinematics of our galaxy. Spiral...
# 2    ASTR_V 403  Introduction to the study of the Universe as a...
# 3    ASTR_V 404  Astronomical instrumentation and techniques fo...
# 4    ASTR_V 405  Experiments in the use of astronomical instrum...
# 5    BIOL_V 112  The principles of cellular and molecular biolo...
# 25   BIOL_V 111  Concepts fundamental to biological issues, suc...
# 26   BIOL_V 121  Principles of storage and transmission of gene...
# 30   BIOL_V 200  Structure and function of plant and animal cel...
# 40   BIOL_V 331  Animal development and its underlying causal p...
# 43   BIOL_V 155  The principles of biology with particular refe...
# 45   CHEM_V 123  Fundamentals of chemical reactivity: thermodyn...
# 75   MATH_V 220  Sets and functions; induction; cardinality;  p...
# 77   BIOL_V 417  Biodiversity from an evolutionary perspective....
# 78   CHEM_V 100  Atomic and molecular properties, chemical reac...
# 79   MATH_V 335  Intensive course with required tutorial. Combi...
# 81   CHEM_V 111  Fundamentals of bonding theories, structural c...
# 82   CHEM_V 115  An introduction to the principles and techniqu...
# 83   CHEM_V 121  Fundamentals of bonding theories and structura...
# 84   PHYS_V 108  Electricity and magnetism, electrical circuits...
# 89   CHEM_V 141  Bonding theories, their predictions, experimen...
# 90   SCIE_V 113  Small-group experience where students study sc...
# 142  CHEM_V 560  Credit will be granted for only one of CHEM 46...
# 143  SCIE_V 300  Effective communication and presentation skill...
# 147  MATH_V 230  A variety of topics in mathematics, showcasing...
# 261  MATH_V 560  Mathematical methods in modelling biological p...
# 263  MATH_V 562  Formulation and analysis of models of excitabl...
# 268  PHYS_V 100  Kinematics, force, energy, momentum, use of gr...
# 269  PHYS_V 106  Classical mechanics including conservation law...
# 311  PHYS_V 117  Kinematics including curvilinear motion. Force...
# 316  PHYS_V 499  Approved and supervised technical work experie...
# 337  SCIE_V 001  An innovative first-year multi-disciplinary co...
# 341  SCIE_V 100  Seminar for First-Year Focus option focused on...
# 426  SCIE_V 500  Overview of methodological approaches to educa...
#
#                                                   reqs
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2            Prerequisite: One of PHYS 200, PHYS 250.
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25                                                 NaN
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79                                                 NaN
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 90                                                 NaN
# 142                                                NaN
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 2...
# 147                                                NaN
# 261                                                NaN
# 263                                                NaN
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311  Prerequisite: One of PHYS 12, PHYS 100. Corequ...
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341                                                NaN
# 426                                                NaN

# %%
def extract_reqs(text, keyword):
    if isinstance(text, str):
        match = re.search(fr'{keyword}:.*?[.\]]', text)
        return match.group(0) if match else ''
    return ''

# Create 'prereqs' and 'coreqs' columns
course_description['prereqs'] = course_description['reqs'].apply(lambda x: extract_reqs(x, 'Prerequisite'))
course_description['coreqs'] = course_description['reqs'].apply(lambda x: extract_reqs(x, 'Corequisite'))
course_description
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_4612\145819628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_description['prereqs'] = course_description['reqs'].apply(lambda x: extract_reqs(x, 'Prerequisite'))
# C:\Users\mahen\AppData\Local\Temp\ipykernel_4612\145819628.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_description['coreqs'] = course_description['reqs'].apply(lambda x: extract_reqs(x, 'Corequisite'))
#          Course                                        Description  \
# 0    ASTR_V 205  Measurement of positions, motions, and distanc...
# 1    ASTR_V 300  Structure and kinematics of our galaxy. Spiral...
# 2    ASTR_V 403  Introduction to the study of the Universe as a...
# 3    ASTR_V 404  Astronomical instrumentation and techniques fo...
# 4    ASTR_V 405  Experiments in the use of astronomical instrum...
# 5    BIOL_V 112  The principles of cellular and molecular biolo...
# 25   BIOL_V 111  Concepts fundamental to biological issues, suc...
# 26   BIOL_V 121  Principles of storage and transmission of gene...
# 30   BIOL_V 200  Structure and function of plant and animal cel...
# 40   BIOL_V 331  Animal development and its underlying causal p...
# 43   BIOL_V 155  The principles of biology with particular refe...
# 45   CHEM_V 123  Fundamentals of chemical reactivity: thermodyn...
# 75   MATH_V 220  Sets and functions; induction; cardinality;  p...
# 77   BIOL_V 417  Biodiversity from an evolutionary perspective....
# 78   CHEM_V 100  Atomic and molecular properties, chemical reac...
# 79   MATH_V 335  Intensive course with required tutorial. Combi...
# 81   CHEM_V 111  Fundamentals of bonding theories, structural c...
# 82   CHEM_V 115  An introduction to the principles and techniqu...
# 83   CHEM_V 121  Fundamentals of bonding theories and structura...
# 84   PHYS_V 108  Electricity and magnetism, electrical circuits...
# 89   CHEM_V 141  Bonding theories, their predictions, experimen...
# 90   SCIE_V 113  Small-group experience where students study sc...
# 142  CHEM_V 560  Credit will be granted for only one of CHEM 46...
# 143  SCIE_V 300  Effective communication and presentation skill...
# 147  MATH_V 230  A variety of topics in mathematics, showcasing...
# 261  MATH_V 560  Mathematical methods in modelling biological p...
# 263  MATH_V 562  Formulation and analysis of models of excitabl...
# 268  PHYS_V 100  Kinematics, force, energy, momentum, use of gr...
# 269  PHYS_V 106  Classical mechanics including conservation law...
# 311  PHYS_V 117  Kinematics including curvilinear motion. Force...
# 316  PHYS_V 499  Approved and supervised technical work experie...
# 337  SCIE_V 001  An innovative first-year multi-disciplinary co...
# 341  SCIE_V 100  Seminar for First-Year Focus option focused on...
# 426  SCIE_V 500  Overview of methodological approaches to educa...
#
#                                                   reqs  \
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2            Prerequisite: One of PHYS 200, PHYS 250.
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25                                                 NaN
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79                                                 NaN
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 90                                                 NaN
# 142                                                NaN
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 2...
# 147                                                NaN
# 261                                                NaN
# 263                                                NaN
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311  Prerequisite: One of PHYS 12, PHYS 100. Corequ...
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341                                                NaN
# 426                                                NaN
#
#                                                prereqs  \
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2             Prerequisite: One of PHYS 200, PHYS 250.
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83             Prerequisite: One of CHEM 12, CHEM 100.
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89             Prerequisite: One of CHEM 12, CHEM 100.
# 90
# 142
# 143
# 147
# 261
# 263
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311            Prerequisite: One of PHYS 12, PHYS 100.
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341
# 426
#
#                                                 coreqs
# 0
# 1    Corequisite: One of MATH 217, MATH 227, MATH 317.
# 2
# 3
# 4
# 5
# 25
# 26
# 30
# 40
# 43
# 45
# 75
# 77
# 78
# 79
# 81
# 82
# 83
# 84
# 89
# 90
# 142
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 241.
# 147
# 261
# 263
# 268
# 269  Corequisite: One of MATH 100, MATH 102, MATH 1...
# 311  Corequisite: One of MATH 100, MATH 102, MATH 1...
# 316
# 337
# 341
# 426

# %%
course_description['prereq_courses'] = course_description['prereqs'].apply(
    lambda x: re.findall(r'[A-Z]{4}\s*\d{3}', str(x)) if isinstance(x, str) else []
)
course_description['coreq_courses'] = course_description['coreqs'].apply(
    lambda x: re.findall(r'[A-Z]{4}\s*\d{3}', str(x)) if isinstance(x, str) else []
)
course_description
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_4612\4123859012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_description['prereq_courses'] = course_description['prereqs'].apply(
# C:\Users\mahen\AppData\Local\Temp\ipykernel_4612\4123859012.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_description['coreq_courses'] = course_description['coreqs'].apply(
#          Course                                        Description  \
# 0    ASTR_V 205  Measurement of positions, motions, and distanc...
# 1    ASTR_V 300  Structure and kinematics of our galaxy. Spiral...
# 2    ASTR_V 403  Introduction to the study of the Universe as a...
# 3    ASTR_V 404  Astronomical instrumentation and techniques fo...
# 4    ASTR_V 405  Experiments in the use of astronomical instrum...
# 5    BIOL_V 112  The principles of cellular and molecular biolo...
# 25   BIOL_V 111  Concepts fundamental to biological issues, suc...
# 26   BIOL_V 121  Principles of storage and transmission of gene...
# 30   BIOL_V 200  Structure and function of plant and animal cel...
# 40   BIOL_V 331  Animal development and its underlying causal p...
# 43   BIOL_V 155  The principles of biology with particular refe...
# 45   CHEM_V 123  Fundamentals of chemical reactivity: thermodyn...
# 75   MATH_V 220  Sets and functions; induction; cardinality;  p...
# 77   BIOL_V 417  Biodiversity from an evolutionary perspective....
# 78   CHEM_V 100  Atomic and molecular properties, chemical reac...
# 79   MATH_V 335  Intensive course with required tutorial. Combi...
# 81   CHEM_V 111  Fundamentals of bonding theories, structural c...
# 82   CHEM_V 115  An introduction to the principles and techniqu...
# 83   CHEM_V 121  Fundamentals of bonding theories and structura...
# 84   PHYS_V 108  Electricity and magnetism, electrical circuits...
# 89   CHEM_V 141  Bonding theories, their predictions, experimen...
# 90   SCIE_V 113  Small-group experience where students study sc...
# 142  CHEM_V 560  Credit will be granted for only one of CHEM 46...
# 143  SCIE_V 300  Effective communication and presentation skill...
# 147  MATH_V 230  A variety of topics in mathematics, showcasing...
# 261  MATH_V 560  Mathematical methods in modelling biological p...
# 263  MATH_V 562  Formulation and analysis of models of excitabl...
# 268  PHYS_V 100  Kinematics, force, energy, momentum, use of gr...
# 269  PHYS_V 106  Classical mechanics including conservation law...
# 311  PHYS_V 117  Kinematics including curvilinear motion. Force...
# 316  PHYS_V 499  Approved and supervised technical work experie...
# 337  SCIE_V 001  An innovative first-year multi-disciplinary co...
# 341  SCIE_V 100  Seminar for First-Year Focus option focused on...
# 426  SCIE_V 500  Overview of methodological approaches to educa...
#
#                                                   reqs  \
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2            Prerequisite: One of PHYS 200, PHYS 250.
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25                                                 NaN
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79                                                 NaN
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 90                                                 NaN
# 142                                                NaN
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 2...
# 147                                                NaN
# 261                                                NaN
# 263                                                NaN
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311  Prerequisite: One of PHYS 12, PHYS 100. Corequ...
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341                                                NaN
# 426                                                NaN
#
#                                                prereqs  \
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2             Prerequisite: One of PHYS 200, PHYS 250.
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83             Prerequisite: One of CHEM 12, CHEM 100.
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89             Prerequisite: One of CHEM 12, CHEM 100.
# 90
# 142
# 143
# 147
# 261
# 263
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311            Prerequisite: One of PHYS 12, PHYS 100.
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341
# 426
#
#                                                 coreqs  \
# 0
# 1    Corequisite: One of MATH 217, MATH 227, MATH 317.
# 2
# 3
# 4
# 5
# 25
# 26
# 30
# 40
# 43
# 45
# 75
# 77
# 78
# 79
# 81
# 82
# 83
# 84
# 89
# 90
# 142
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 241.
# 147
# 261
# 263
# 268
# 269  Corequisite: One of MATH 100, MATH 102, MATH 1...
# 311  Corequisite: One of MATH 100, MATH 102, MATH 1...
# 316
# 337
# 341
# 426
#
#                                         prereq_courses  \
# 0    [ASTR 200, PHYS 210, EOSC 211, CPSC 302, CPSC ...
# 1    [ASTR 205, PHYS 210, EOSC 211, CPSC 302, CPSC ...
# 2                                 [PHYS 200, PHYS 250]
# 3             [PHYS 210, PHYS 408, PHYS 312, MATH 316]
# 4                                            [ASTR404]
# 5             [CHEM 100, CHEM 110, CHEM 111, BIOL 111]
# 25                                                  []
# 26                                          [BIOL 111]
# 30            [BIOL 112, CHEM 123, CHEM 130, SCIE 001]
# 40   [BIOL 201, BIOL 200, BIOL 260, BIOL 233, BIOL ...
# 43            [CHEM 100, CHEM 110, CHEM 111, BIOL 111]
# 45                      [CHEM 111, CHEM 121, CHEM 141]
# 75   [MATH 101, MATH 103, MATH 105, SCIE 001, MATH ...
# 77                      [BIOL 200, BIOL 233, BIOL 234]
# 78                                                  []
# 79                                                  []
# 81                                                  []
# 82                                [CHEM 110, CHEM 120]
# 83                                          [CHEM 100]
# 84   [PHYS 106, PHYS 107, PHYS 101, PHYS 117, PHYS ...
# 89                                          [CHEM 100]
# 90                                                  []
# 142                                                 []
# 143                                                 []
# 147                                                 []
# 261                                                 []
# 263                                                 []
# 268                                                 []
# 269                                         [PHYS 100]
# 311                                         [PHYS 100]
# 316                                          [PHYS498]
# 337                                                 []
# 341                                                 []
# 426                                                 []
#
#                                          coreq_courses
# 0                                                   []
# 1                       [MATH 217, MATH 227, MATH 317]
# 2                                                   []
# 3                                                   []
# 4                                                   []
# 5                                                   []
# 25                                                  []
# 26                                                  []
# 30                                                  []
# 40                                                  []
# 43                                                  []
# 45                                                  []
# 75                                                  []
# 77                                                  []
# 78                                                  []
# 79                                                  []
# 81                                                  []
# 82                                                  []
# 83                                                  []
# 84                                                  []
# 89                                                  []
# 90                                                  []
# 142                                                 []
# 143                     [BIOL 300, STAT 200, STAT 241]
# 147                                                 []
# 261                                                 []
# 263                                                 []
# 268                                                 []
# 269  [MATH 100, MATH 102, MATH 104, MATH 120, MATH ...
# 311  [MATH 100, MATH 102, MATH 104, MATH 110, MATH ...
# 316                                                 []
# 337                                                 []
# 341                                                 []
# 426                                                 []

# %%
course_description.drop(columns=['prereqs', 'coreqs'], inplace=True)
course_description
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_4612\3400389462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   course_description.drop(columns=['prereqs', 'coreqs'], inplace=True)
#          Course                                        Description  \
# 0    ASTR_V 205  Measurement of positions, motions, and distanc...
# 1    ASTR_V 300  Structure and kinematics of our galaxy. Spiral...
# 2    ASTR_V 403  Introduction to the study of the Universe as a...
# 3    ASTR_V 404  Astronomical instrumentation and techniques fo...
# 4    ASTR_V 405  Experiments in the use of astronomical instrum...
# 5    BIOL_V 112  The principles of cellular and molecular biolo...
# 25   BIOL_V 111  Concepts fundamental to biological issues, suc...
# 26   BIOL_V 121  Principles of storage and transmission of gene...
# 30   BIOL_V 200  Structure and function of plant and animal cel...
# 40   BIOL_V 331  Animal development and its underlying causal p...
# 43   BIOL_V 155  The principles of biology with particular refe...
# 45   CHEM_V 123  Fundamentals of chemical reactivity: thermodyn...
# 75   MATH_V 220  Sets and functions; induction; cardinality;  p...
# 77   BIOL_V 417  Biodiversity from an evolutionary perspective....
# 78   CHEM_V 100  Atomic and molecular properties, chemical reac...
# 79   MATH_V 335  Intensive course with required tutorial. Combi...
# 81   CHEM_V 111  Fundamentals of bonding theories, structural c...
# 82   CHEM_V 115  An introduction to the principles and techniqu...
# 83   CHEM_V 121  Fundamentals of bonding theories and structura...
# 84   PHYS_V 108  Electricity and magnetism, electrical circuits...
# 89   CHEM_V 141  Bonding theories, their predictions, experimen...
# 90   SCIE_V 113  Small-group experience where students study sc...
# 142  CHEM_V 560  Credit will be granted for only one of CHEM 46...
# 143  SCIE_V 300  Effective communication and presentation skill...
# 147  MATH_V 230  A variety of topics in mathematics, showcasing...
# 261  MATH_V 560  Mathematical methods in modelling biological p...
# 263  MATH_V 562  Formulation and analysis of models of excitabl...
# 268  PHYS_V 100  Kinematics, force, energy, momentum, use of gr...
# 269  PHYS_V 106  Classical mechanics including conservation law...
# 311  PHYS_V 117  Kinematics including curvilinear motion. Force...
# 316  PHYS_V 499  Approved and supervised technical work experie...
# 337  SCIE_V 001  An innovative first-year multi-disciplinary co...
# 341  SCIE_V 100  Seminar for First-Year Focus option focused on...
# 426  SCIE_V 500  Overview of methodological approaches to educa...
#
#                                                   reqs  \
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2            Prerequisite: One of PHYS 200, PHYS 250.
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25                                                 NaN
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79                                                 NaN
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 90                                                 NaN
# 142                                                NaN
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 2...
# 147                                                NaN
# 261                                                NaN
# 263                                                NaN
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311  Prerequisite: One of PHYS 12, PHYS 100. Corequ...
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341                                                NaN
# 426                                                NaN
#
#                                         prereq_courses  \
# 0    [ASTR 200, PHYS 210, EOSC 211, CPSC 302, CPSC ...
# 1    [ASTR 205, PHYS 210, EOSC 211, CPSC 302, CPSC ...
# 2                                 [PHYS 200, PHYS 250]
# 3             [PHYS 210, PHYS 408, PHYS 312, MATH 316]
# 4                                            [ASTR404]
# 5             [CHEM 100, CHEM 110, CHEM 111, BIOL 111]
# 25                                                  []
# 26                                          [BIOL 111]
# 30            [BIOL 112, CHEM 123, CHEM 130, SCIE 001]
# 40   [BIOL 201, BIOL 200, BIOL 260, BIOL 233, BIOL ...
# 43            [CHEM 100, CHEM 110, CHEM 111, BIOL 111]
# 45                      [CHEM 111, CHEM 121, CHEM 141]
# 75   [MATH 101, MATH 103, MATH 105, SCIE 001, MATH ...
# 77                      [BIOL 200, BIOL 233, BIOL 234]
# 78                                                  []
# 79                                                  []
# 81                                                  []
# 82                                [CHEM 110, CHEM 120]
# 83                                          [CHEM 100]
# 84   [PHYS 106, PHYS 107, PHYS 101, PHYS 117, PHYS ...
# 89                                          [CHEM 100]
# 90                                                  []
# 142                                                 []
# 143                                                 []
# 147                                                 []
# 261                                                 []
# 263                                                 []
# 268                                                 []
# 269                                         [PHYS 100]
# 311                                         [PHYS 100]
# 316                                          [PHYS498]
# 337                                                 []
# 341                                                 []
# 426                                                 []
#
#                                          coreq_courses
# 0                                                   []
# 1                       [MATH 217, MATH 227, MATH 317]
# 2                                                   []
# 3                                                   []
# 4                                                   []
# 5                                                   []
# 25                                                  []
# 26                                                  []
# 30                                                  []
# 40                                                  []
# 43                                                  []
# 45                                                  []
# 75                                                  []
# 77                                                  []
# 78                                                  []
# 79                                                  []
# 81                                                  []
# 82                                                  []
# 83                                                  []
# 84                                                  []
# 89                                                  []
# 90                                                  []
# 142                                                 []
# 143                     [BIOL 300, STAT 200, STAT 241]
# 147                                                 []
# 261                                                 []
# 263                                                 []
# 268                                                 []
# 269  [MATH 100, MATH 102, MATH 104, MATH 120, MATH ...
# 311  [MATH 100, MATH 102, MATH 104, MATH 110, MATH ...
# 316                                                 []
# 337                                                 []
# 341                                                 []
# 426                                                 []

# %%
course_description[['reqs', 'prereq_courses', 'coreq_courses']]
# Out:
#                                                   reqs  \
# 0    Prerequisite: ASTR 200 and one of PHYS 210, EO...
# 1    Prerequisite: ASTR 205 and one of PHYS 210, EO...
# 2            Prerequisite: One of PHYS 200, PHYS 250.
# 3    Prerequisite: All of PHYS 210, PHYS 408 and on...
# 4                              Prerequisite: [ASTR404]
# 5    Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 25                                                 NaN
# 26    Prerequisite: One of BIOL 11, BIOL 12, BIOL 111.
# 30   Prerequisite: Either (a) BIOL 112 and one of C...
# 40   Prerequisite: Either (a) BIOL 201 or (b) all o...
# 43   Prerequisite: One of CHEM 12, CHEM 100, CHEM 1...
# 45   Prerequisite: One of CHEM 111, CHEM 121, CHEM ...
# 75   Prerequisite: Either (a) a score of 64% or hig...
# 77   Prerequisite: BIOL 200 and one of BIOL 233, BI...
# 78   Prerequisite: Not open to students with credit...
# 79                                                 NaN
# 81   Prerequisite: Not open to students with credit...
# 82            Prerequisite: One of CHEM 110, CHEM 120.
# 83   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 84   Prerequisite: Either (a) one of PHYS 106, PHYS...
# 89   Prerequisite: One of CHEM 12, CHEM 100. Equiva...
# 90                                                 NaN
# 142                                                NaN
# 143  Corequisite: One of BIOL 300, STAT 200, STAT 2...
# 147                                                NaN
# 261                                                NaN
# 263                                                NaN
# 268  Prerequisite: Not open to students with credit...
# 269  Prerequisite: Either (a) a score more than 85%...
# 311  Prerequisite: One of PHYS 12, PHYS 100. Corequ...
# 316                            Prerequisite: [PHYS498]
# 337  Prerequisite: All of: CALC 12, ENGL 12, and Pr...
# 341                                                NaN
# 426                                                NaN
#
#                                         prereq_courses  \
# 0    [ASTR 200, PHYS 210, EOSC 211, CPSC 302, CPSC ...
# 1    [ASTR 205, PHYS 210, EOSC 211, CPSC 302, CPSC ...
# 2                                 [PHYS 200, PHYS 250]
# 3             [PHYS 210, PHYS 408, PHYS 312, MATH 316]
# 4                                            [ASTR404]
# 5             [CHEM 100, CHEM 110, CHEM 111, BIOL 111]
# 25                                                  []
# 26                                          [BIOL 111]
# 30            [BIOL 112, CHEM 123, CHEM 130, SCIE 001]
# 40   [BIOL 201, BIOL 200, BIOL 260, BIOL 233, BIOL ...
# 43            [CHEM 100, CHEM 110, CHEM 111, BIOL 111]
# 45                      [CHEM 111, CHEM 121, CHEM 141]
# 75   [MATH 101, MATH 103, MATH 105, SCIE 001, MATH ...
# 77                      [BIOL 200, BIOL 233, BIOL 234]
# 78                                                  []
# 79                                                  []
# 81                                                  []
# 82                                [CHEM 110, CHEM 120]
# 83                                          [CHEM 100]
# 84   [PHYS 106, PHYS 107, PHYS 101, PHYS 117, PHYS ...
# 89                                          [CHEM 100]
# 90                                                  []
# 142                                                 []
# 143                                                 []
# 147                                                 []
# 261                                                 []
# 263                                                 []
# 268                                                 []
# 269                                         [PHYS 100]
# 311                                         [PHYS 100]
# 316                                          [PHYS498]
# 337                                                 []
# 341                                                 []
# 426                                                 []
#
#                                          coreq_courses
# 0                                                   []
# 1                       [MATH 217, MATH 227, MATH 317]
# 2                                                   []
# 3                                                   []
# 4                                                   []
# 5                                                   []
# 25                                                  []
# 26                                                  []
# 30                                                  []
# 40                                                  []
# 43                                                  []
# 45                                                  []
# 75                                                  []
# 77                                                  []
# 78                                                  []
# 79                                                  []
# 81                                                  []
# 82                                                  []
# 83                                                  []
# 84                                                  []
# 89                                                  []
# 90                                                  []
# 142                                                 []
# 143                     [BIOL 300, STAT 200, STAT 241]
# 147                                                 []
# 261                                                 []
# 263                                                 []
# 268                                                 []
# 269  [MATH 100, MATH 102, MATH 104, MATH 120, MATH ...
# 311  [MATH 100, MATH 102, MATH 104, MATH 110, MATH ...
# 316                                                 []
# 337                                                 []
# 341                                                 []
# 426                                                 []
